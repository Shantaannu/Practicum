# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join("..", "Src")))

from log.utils.logger import setup_logger
# Out:
# logger.py location: e:\Practicum Project\Practicum\Src\log\utils\logger.py
# Log directory: e:\Practicum Project\Practicum\Src\log\Log_Data

# %%
logger = setup_logger("Normalization Notebook")

# %%
logger.info("Notebook Started")
# Out:
# 2026-06-23 23:06:44 | INFO | Notebook Started

# %%
print("Hello World")
# Out:
# Hello World

# %%
logger.info("Notebook Executed Successfully")
# Out:
# 2026-06-23 23:03:00,126 | INFO | Notebook Executed Successfully

# %% [markdown]
# One-hot encode categorical variables

# %%
categorical_cols = [
    "position",
    "session_type",
    "team",
    "quarter",
    "running_type"
]

# %%
df = pd.get_dummies(
    df,
    columns=categorical_cols,
    drop_first=True
)

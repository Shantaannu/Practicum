# %%
# !pip install pandas pyarrow fastparquet
# Out:
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ----------------------------- ---------- 7.1/9.8 MB 39.6 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 33.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/27.4 MB ? eta -:--:--
#    --------- ------------------------------ 6.8/27.4 MB 35.0 MB/s eta 0:00:01
#    --------------------- ------------------ 14.4/27.4 MB 36.3 MB/s eta 0:00:01
#    ------------------------------- -------- 21.8/27.4 MB 35.3 MB/s eta 0:00:01
#    ---------------------------------------- 27.4/27.4 MB 33.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/695.7 kB ? eta -:--:--
#    --------------------------------------- 695.7/695.7 kB 27.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 23.0 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

df = pd.read_parquet("data/raw/your_file.parquet")

print(df.head())
print(df.shape)
print(df.columns)

# %%
import pandas as pd
import numpy as np

# %%
wellness_df = pd.read_csv("processed/wellness_training_processed.csv")
session_df = pd.read_csv("processed/training_session_features.csv")

master_df = wellness_df.merge(
    session_df,
    on=["athlete_id", "date"],
    how="left"
)

master_df.to_csv("processed/master_dataset.csv", index=False)
